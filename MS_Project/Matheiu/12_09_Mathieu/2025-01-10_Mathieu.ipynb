# %%
import numpy as np
import scipy as sp
import sympy as sy

import matplotlib as mpl
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import scipy.special as spe
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import colormaps
from matplotlib.gridspec import GridSpec
from matplotlib.patches import Rectangle
from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

from sympy import *

# %%
gs = GridSpec(nrows=1, ncols=2, width_ratios=[1,1], height_ratios=[1])
cmaps = plt.colormaps()

blues = mpl.colormaps["Blues"].resampled(30)
purples = mpl.colormaps["Purples"].resampled(22)
reds = mpl.colormaps["Reds"].resampled(12)
orange = mpl.colormaps["YlOrBr"].resampled(22)
green = mpl.colormaps["YlGn"].resampled(30)
spectrum = mpl.colormaps["viridis"].resampled(30)

# %%
c_blues = [blues(i) for i in range(12)]
c_purp = [purples(i) for i in range(22)]
c_red = [reds(i) for i in range(12)]
c_orag = [orange(i) for i in range(22)]
c_spec = [spectrum(i) for i in range(10)]
c_gree = [green(i) for i in range(12)]

# %%
# 파라미터 범위 설정
m_range = np.arange(0, 1, 1)  # m 값 범위
q_range = np.linspace(0, 10, 50)  # q 값 범위
x = np.linspace(0, 180, 120)  # x 값 범위 (도 단위)

# 3D 그래프 준비
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# 각 m에 대해 표면 그리기
for m in m_range:
    Q, X = np.meshgrid(q_range, x)
    Z = np.array([spe.mathieu_cem(m, q, x)[0] for q, x in zip(Q.flatten(), X.flatten())]).reshape(Q.shape)
    
    surf = ax.plot_surface(Q, X, Z, cmap=spectrum, alpha=0.7)

# 그래프 설정
ax.set_xlabel('q')
ax.set_ylabel('x (degrees)')
ax.set_zlabel('ce_m(x, q)')
ax.set_title(f'Mathieu Even Function (ce_m) for m = {m_range[0]} to {m_range[-1]}')

# 컬러바 추가
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

plt.show()

# %%
# 파라미터 범위 설정
m_range = np.arange(0, 1, 1)  # m 값 범위
q_range = np.linspace(0, 10, 50)  # q 값 범위
x = np.linspace(0, 180, 120)  # x 값 범위 (도 단위)

# 3D 그래프 준비
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# 각 m에 대해 표면 그리기
for m in m_range:
    Q, X = np.meshgrid(q_range, x)
    Z = np.array([spe.mathieu_cem(m, q, x)[1] for q, x in zip(Q.flatten(), X.flatten())]).reshape(Q.shape)
    
    surf = ax.plot_surface(Q, X, Z, cmap=orange, alpha=0.7)

# 그래프 설정
ax.set_xlabel('q')
ax.set_ylabel('x (degrees)')
ax.set_zlabel('ce_m(x, q)')
ax.set_title(f'Mathieu Even Function (ce_m) for m = {m_range[0]} to {m_range[-1]}')
ax.view_init(elev=0, azim=0)

# 컬러바 추가
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

plt.show()

# %%
# 파라미터 범위 설정
m_range = np.arange(0, 2, 1)  # m 값 범위
q_range = np.linspace(0, 10, 50)  # q 값 범위
x = np.linspace(0, 360, 100)  # x 값 범위 (도 단위)

# 3D 그래프 준비
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# 각 m에 대해 표면 그리기
for m in range(1,2,1):
    Q, X = np.meshgrid(q_range, x)
    Z = np.array([spe.mathieu_sem(m, q, x)[0] for q, x in zip(Q.flatten(), X.flatten())]).reshape(Q.shape)
    
    surf = ax.plot_surface(Q, X, Z, cmap=green, alpha=0.7)

# 그래프 설정
ax.set_xlabel('q')
ax.set_ylabel('x (degrees)')
ax.set_zlabel('se_m(x, q)')
ax.set_title(f'Mathieu Odd Function (se_m) for m = {m_range[0]} to {m_range[-1]}')
ax.view_init(elev=0, azim=0)

# 컬러바 추가
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

plt.show()

# %%
# 파라미터 범위 설정
m_range = np.arange(0, 2, 1)  # m 값 범위
q_range = np.linspace(0, 10, 50)  # q 값 범위
x = np.linspace(0, 360, 100)  # x 값 범위 (도 단위)

# 3D 그래프 준비
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# 각 m에 대해 표면 그리기
for m in range(2,3,1):
    Q, X = np.meshgrid(q_range, x)
    Z = np.array([spe.mathieu_sem(m, q, x)[1] for q, x in zip(Q.flatten(), X.flatten())]).reshape(Q.shape)
    
    surf = ax.plot_surface(Q, X, Z, cmap=blues, alpha=0.7)

# 그래프 설정
ax.set_xlabel('q')
ax.set_ylabel('x (degrees)')
ax.set_zlabel('se_m(x, q)')
ax.set_title(f'Mathieu Odd Function (se_m) for m = {m_range[0]} to {m_range[-1]}')
ax.view_init(elev=0, azim=0)

# 컬러바 추가
fig.colorbar(surf, ax=ax, shrink=0.5, aspect=5)

plt.show()

# %% [markdown]
# Eigenvalue check

# %%
gam_arr = np.linspace(0,10,100)

for i in range(0,3,1):
    plt.plot(gam_arr,spe.mathieu_a(i,gam_arr))
    plt.plot(gam_arr,spe.mathieu_b(i,gam_arr))

# %%
plt.plot(gam_arr,spe.mathieu_sem(1,1,gam_arr)[0])

# %% [markdown]
# Mathieu characteristic exponent

# %%
def chi(n,p):
    return n + np.mod(n,2) + (-1)**n * 2 * np.abs(p - np.round(p))

p_arr = np.linspace(0,2,1000)
plt.plot(p_arr,chi(0,p_arr),label = "ground state?")
plt.plot(p_arr,chi(1,p_arr),label = "excited state?")
plt.plot(p_arr,chi(2,p_arr),label = "2nd excited state?")

plt.legend()
plt.show()
