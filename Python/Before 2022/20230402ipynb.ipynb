# %%
import sympy as sp
import numpy as np
import scipy as sc
import math
from sympy.plotting import plot
from sympy.plotting import plot3d

sp.init_printing(use_latex=True)

# %%
x, y = sp.symbols('x y')
a,b = 4,2
X,Y,Z=1,1,3

E=(Z/((x-X)**2+(y-Y)**2+Z**2))

I=sp.integrate(E,(y,0,1))
I2=sp.integrate(I,(x,0,1))

#E_x=sp.symbols('E_x',type='Function')
#E = sp.symbols('E',type='Function')


#E=sp.integrate(Z/((x-X)**2-(y-Y)**2-Z)**3/2,(x,0,2),(y,0,2))
#E = sp.integrate(E_x,(y,-b/2,b/2))

plot3d(I2,(x,-1,1),(y,-1,1))
sss
#E=sp.integrate(1/(x+y+Z),x)
#E_y=sp.integrate(E,y)

#plot3d(E_y,(x,-5,5),(y,-5,5))
# Out:
# /Users/e2_602_qma/opt/anaconda3/envs/Workspace/lib/python3.9/site-packages/sympy/plotting/experimental_lambdify.py:142: UserWarning: The evaluation of the expression is problematic. We are trying a failback method that may still work. Please report this as a bug.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~/opt/anaconda3/envs/Workspace/lib/python3.9/site-packages/sympy/plotting/experimental_lambdify.py:131, in vectorized_lambdify.__call__(self, *args)
#     130 temp_args = (np.array(a, dtype=complex) for a in args)
# --> 131 results = self.vector_func(*temp_args)
#     132 results = np.ma.masked_where(
#     133     np.abs(results.imag) > 1e-7 * np.abs(results),
#     134     results.real, copy=False)
#
# ...

# %%
I
# Out:
#         _________________    ⎛           _________________              ______
#        ╱       -1            ⎜   6      ╱       -1              5      ╱
# 9⋅    ╱  ─────────────── ⋅log⎜- x ⋅    ╱  ───────────────  + 6⋅x ⋅    ╱  ─────
#      ╱                 5     ⎜        ╱                 5            ╱
#     ╱    ⎛ 2          ⎞      ⎜       ╱    ⎛ 2          ⎞            ╱    ⎛ 2
#   ╲╱     ⎝x  - 2⋅x + 4⎠      ⎝     ╲╱     ⎝x  - 2⋅x + 4⎠          ╲╱     ⎝x  -
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
# ___________               _________________               _________________
#  -1               4      ╱       -1               3      ╱       -1
# ──────────  - 24⋅x ⋅    ╱  ───────────────  + 56⋅x ⋅    ╱  ───────────────  -
#          5             ╱                 5             ╱                 5
#         ⎞             ╱    ⎛ 2          ⎞             ╱    ⎛ 2          ⎞
# ...

# %%
f = lambda y, x : 3/((x-1)**2+(y-1)**2+3**2)**(3/2)

a=np.linspace(0,2,100)
b=np.linspace(0,1,100)

I=sc.integrate.dblquad(f, a, -a, b, -b)

print(I)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[47], line 6
#       3 a=np.linspace(0,2,100)
#       4 b=np.linspace(0,1,100)
# ----> 6 I=sc.integrate.dblquad(f, a, -a, b, -b)
#       8 print(I)
#
# File ~/opt/anaconda3/envs/Workspace/lib/python3.9/site-packages/scipy/integrate/_quadpack_py.py:771, in dblquad(func, a, b, gfun, hfun, args, epsabs, epsrel)
#     767 def temp_ranges(*args):
#     768     return [gfun(args[0]) if callable(gfun) else gfun,
#     769             hfun(args[0]) if callable(hfun) else hfun]
# --> 771 return nquad(func, [temp_ranges, [a, b]], args=args,
#     772         opts={"epsabs": epsabs, "epsrel": epsrel})
#
# File ~/opt/anaconda3/envs/Workspace/lib/python3.9/site-packages/scipy/integrate/_quadpack_py.py:1171, in nquad(func, ranges, args, opts, full_output)
#    1169 else:
# ...
