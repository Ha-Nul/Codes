# %%
import matplotlib.pyplot as plt
import numpy as np
import sympy as sp
import math

# %%
t=sp.symbols('t')

def r(n):
    radius=n
    return radius

x=sp.cos(t)
y=sp.sin(t)

in_radi=2/sp.sqrt(x**2+1)
sp.plot(in_radi,(t,0,2*sp.pi))
