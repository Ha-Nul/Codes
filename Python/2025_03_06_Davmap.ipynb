# %%
from sympy import *

init_printing()

# %%
a = symbols('a')
p = symbols('p')
c = symbols('c')

Davmap = Matrix([[1-a,0,0,a*p/(1-p)],[0,c,0,0],[0,0,c,0],[a,0,0,1-a*p/(1-p)]])

# %%
Davmap
# Out:
# ⎡                 a⋅p    ⎤
# ⎢1 - a  0  0     ─────   ⎥
# ⎢                1 - p   ⎥
# ⎢                        ⎥
# ⎢  0    c  0       0     ⎥
# ⎢                        ⎥
# ⎢  0    0  c       0     ⎥
# ⎢                        ⎥
# ⎢                a⋅p     ⎥
# ⎢  a    0  0  - ───── + 1⎥
# ⎣               1 - p    ⎦

# %%
P, D = Davmap.diagonalize()

# %%
D
# Out:
# ⎡1  0  0      0    ⎤
# ⎢                  ⎥
# ⎢0  c  0      0    ⎥
# ⎢                  ⎥
# ⎢0  0  c      0    ⎥
# ⎢                  ⎥
# ⎢         a + p - 1⎥
# ⎢0  0  0  ─────────⎥
# ⎣           p - 1  ⎦

# %%
exp(Davmap)
# Out:
# ⎡                  a + p - 1                    a + p - 1        ⎤
# ⎢                  ─────────                    ─────────        ⎥
# ⎢                    p - 1                        p - 1          ⎥
# ⎢   ℯ⋅p - (p - 1)⋅ℯ              0   0     - p⋅ℯ          + ℯ⋅p  ⎥
# ⎢                                                                ⎥
# ⎢                                 c                              ⎥
# ⎢              0                 ℯ   0              0            ⎥
# ⎢                                                                ⎥
# ⎢                                     c                          ⎥
# ⎢              0                 0   ℯ              0            ⎥
# ⎢                                                                ⎥
# ⎢                     a + p - 1             a + p - 1            ⎥
# ⎢                     ─────────             ─────────            ⎥
# ⎢                       p - 1                 p - 1              ⎥
# ...

# %%
Davmap @ Davmap.transpose()
# Out:
# ⎡                                           ⎛   a⋅p     ⎞            ⎤
# ⎢       2  2                            a⋅p⋅⎜- ───── + 1⎟            ⎥
# ⎢      a ⋅p             2                   ⎝  1 - p    ⎠            ⎥
# ⎢     ──────── + (1 - a)        0   0   ───────────────── + a⋅(1 - a)⎥
# ⎢            2                                1 - p                  ⎥
# ⎢     (1 - p)                                                        ⎥
# ⎢                                                                    ⎥
# ⎢                                2                                   ⎥
# ⎢              0                c   0                 0              ⎥
# ⎢                                                                    ⎥
# ⎢                                    2                               ⎥
# ⎢              0                0   c                 0              ⎥
# ⎢                                                                    ⎥
# ...

# %%
Davmap.transpose() @ Davmap
# Out:
# ⎡         2          2                  a⋅p⋅(1 - a)     ⎛   a⋅p     ⎞⎤
# ⎢        a  + (1 - a)           0   0   ─────────── + a⋅⎜- ───── + 1⎟⎥
# ⎢                                          1 - p        ⎝  1 - p    ⎠⎥
# ⎢                                                                    ⎥
# ⎢                                2                                   ⎥
# ⎢              0                c   0                 0              ⎥
# ⎢                                                                    ⎥
# ⎢                                    2                               ⎥
# ⎢              0                0   c                 0              ⎥
# ⎢                                                                    ⎥
# ⎢                                           2  2                  2  ⎥
# ⎢a⋅p⋅(1 - a)     ⎛   a⋅p     ⎞             a ⋅p      ⎛   a⋅p     ⎞   ⎥
# ⎢─────────── + a⋅⎜- ───── + 1⎟  0   0     ──────── + ⎜- ───── + 1⎟   ⎥
# ...

# %%
Davmap2 = Matrix([[1-a,0,0,a],[0,c,0,0],[0,0,c,0],[a,0,0,1]])

# %%
P2, D2 = Davmap2.diagonalize()

# %%
D2
# Out:
# ⎡c  0        0               0       ⎤
# ⎢                                    ⎥
# ⎢0  c        0               0       ⎥
# ⎢                                    ⎥
# ⎢        a   √5⋅a                    ⎥
# ⎢0  0  - ─ + ──── + 1        0       ⎥
# ⎢        2    2                      ⎥
# ⎢                                    ⎥
# ⎢                        √5⋅a   a    ⎥
# ⎢0  0        0         - ──── - ─ + 1⎥
# ⎣                         2     2    ⎦

# %%
Genmap = Matrix([[a,c],[c,1-a]])

# %%
GP, GD = Genmap.diagonalize()

# %%
exp(Genmap)
# Out:
# ⎡                           _______________________                            ↪
# ⎢                          ╱    2            2                                 ↪
# ⎢                    1   ╲╱  4⋅a  - 4⋅a + 4⋅c  + 1                             ↪
# ⎢                    ─ - ──────────────────────────                            ↪
# ⎢                 2  2               2                                         ↪
# ⎢              2⋅c ⋅ℯ                                                          ↪
# ⎢───────────────────────────────────────────────────────────────── - ───────── ↪
# ⎢⎛         _______________________    ⎞    _______________________   ⎛         ↪
# ⎢⎜        ╱    2            2         ⎟   ╱    2            2        ⎜         ↪
# ⎢⎝2⋅a + ╲╱  4⋅a  - 4⋅a + 4⋅c  + 1  - 1⎠⋅╲╱  4⋅a  - 4⋅a + 4⋅c  + 1    ⎝2⋅a - ╲╱ ↪
# ⎢                                                                              ↪
# ⎢                                           _______________________         __ ↪
# ...
