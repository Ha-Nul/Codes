# %%
import numpy as np

# %%
def gaus(x):
    return np.exp(-(x - x0)**2 / (2 * sigma**2)) * np.exp(1j * p0 * x / self.hbar)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 gaus = np.exp(-(x - x0)**2 / (2 * sigma**2)) * np.exp(1j * p0 * x / self.hbar)
#
# NameError: name 'x' is not defined
