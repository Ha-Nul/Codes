# %%
import numpy as np
import scipy.constants as ct
import matplotlib.pyplot as plt

# %%
x=np.linspace(-40,40,300)

unit = 1e-21

def bose_dist(x):

    T = 273
    boltz = ct.k*T
    dist = 1/(np.exp(x*unit/boltz)-1)

    plt.plot(x,dist)
    plt.show

    return

# %%
def dist_function(x):

    T = 273s
    boltz = ct.k*T
    bose_dist = 1/(np.exp(x*unit/boltz)-1)
    fermi_dist = 1/(np.exp(x*unit/boltz)+1)

    plt.plot(x,fermi_dist,color="firebrick")
    plt.plot(x,bose_dist,color="cornflowerblue")
    plt.ylim(-0.2,1.2)
    plt.show

    return

# %%
dist_function(x)

# %%
x
# Out:
# array([-40.        , -39.73244147, -39.46488294, -39.19732441,
#        -38.92976589, -38.66220736, -38.39464883, -38.1270903 ,
#        -37.85953177, -37.59197324, -37.32441472, -37.05685619,
#        -36.78929766, -36.52173913, -36.2541806 , -35.98662207,
#        -35.71906355, -35.45150502, -35.18394649, -34.91638796,
#        -34.64882943, -34.3812709 , -34.11371237, -33.84615385,
#        -33.57859532, -33.31103679, -33.04347826, -32.77591973,
#        -32.5083612 , -32.24080268, -31.97324415, -31.70568562,
#        -31.43812709, -31.17056856, -30.90301003, -30.63545151,
#        -30.36789298, -30.10033445, -29.83277592, -29.56521739,
#        -29.29765886, -29.03010033, -28.76254181, -28.49498328,
#        -28.22742475, -27.95986622, -27.69230769, -27.42474916,
#        -27.15719064, -26.88963211, -26.62207358, -26.35451505,
#        -26.08695652, -25.81939799, -25.55183946, -25.28428094,
#        -25.01672241, -24.74916388, -24.48160535, -24.21404682,
# ...

# %%
dist_function(10)
