# %%
import Test as T
import matplotlib.pyplot as plt
import numpy as np

# %%
ome = np.linspace(0,5,200)

def plotting(r,g):
    A =[]
    for i in range(len(ome)):
        om = np.linspace(0,5,200)

        H = T.Spectral_Function(10,r,2,g,om[i],0.01,0.5)
        A.append(H)
    
    return(A)

plt.plot(ome,plotting(0,0))

# %%
plt.figure(figsize=(12,9))

plt.subplot(2,2,1)
plt.plot(ome,plotting(0,0.1),label=r'g=0.1,$\gamma$=0')
plt.plot(ome,plotting(1,0.1),label=r'g=0.1,$\gamma$=1')
A = np.max(plotting(0,0.1))
A_1 = np.max(plotting(1,0.1))
plt.text(1.8,120,A)
plt.text(2.5,167,A_1)
plt.xlabel('Matsubara Freq')
plt.legend()

plt.subplot(2,2,2)
plt.plot(ome,plotting(0,0.2),label=r'g=0.2,$\gamma$=0')
plt.plot(ome,plotting(1,0.2),label=r'g=0.2,$\gamma$=1')
B = np.max(plotting(0,0.2))
B_1 = np.max(plotting(1,0.2))
plt.text(1.8,110,B)
plt.text(2.5,160,B_1)
plt.xlabel('Matsubara Freq')
plt.legend()

plt.subplot(2,2,3)
C = np.max(plotting(0,0.3))
C_1 = np.max(plotting(1,0.3))
plt.plot(ome,plotting(0,0.3),label=r'g=0.3,$\gamma$=0')
plt.plot(ome,plotting(1,0.3),label=r'g=0.3,$\gamma$=1')
plt.text(1.8,100,C)
plt.text(2.5,152,C_1)
plt.xlabel('Matsubara Freq')
plt.legend()

plt.subplot(2,2,4)
D = np.max(plotting(0,0.4))
D_1 = np.max(plotting(1,0.4))
plt.plot(ome,plotting(0,0.4),label=r'g=0.4,$\gamma$=0')
plt.plot(ome,plotting(1,0.4),label=r'g=0.4,$\gamma$=1')
plt.xlabel('Matsubara Freq')
plt.text(1.8,95,D)
plt.text(2.5,140,D_1)
plt.legend()

plt.show()

# %%
E = np.max(plotting(0,0.5))
E_1 = np.max(plotting(1,0.5))
plt.plot(ome,plotting(0,0.5),label=r'g=0.5,$\gamma$=0')
plt.plot(ome,plotting(1,0.5),label=r'g=0.5,$\gamma$=1')
plt.text(1.8,90,E)
plt.text(2.5,135,E_1)
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,7))

plt.subplot(2,2,1)
plt.plot(ome,plotting(1,0.1),label='g = 0.1')
plt.xlabel('Matsubara Freq')
plt.legend()


plt.subplot(2,2,2)
plt.plot(ome,plotting(1,0.2),label="Gamma = 0.2")
plt.xlabel('Matsubara Freq')
plt.legend()

plt.subplot(2,2,3)
plt.xlabel('Matsubara Freq')
plt.plot(ome, plotting(1,0.3),label)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 16
#      14 plt.subplot(2,2,3)
#      15 plt.xlabel('Matsubara Freq')
# ---> 16 plt.plot(ome, plotting(1,0.3),label)
#      18 plt.show()
#
# NameError: name 'label' is not defined

# %%
AB = T.Standard_even_Eigenval(1,4,1)
AC = T.Standard_even_Eigenvec(1,4,1)

print(AB,AC)
