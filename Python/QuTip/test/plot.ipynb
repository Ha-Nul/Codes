# %%
import numpy as np
import pandas as pd
import matplotlib as mpl

import matplotlib.pyplot as plt
from matplotlib.colors import LinearSegmentedColormap
from matplotlib import colormaps
from matplotlib.gridspec import GridSpec

# %%
gs = GridSpec(nrows=1, ncols=2, width_ratios=[1,1], height_ratios=[1])
cmaps = plt.colormaps()

blues = mpl.colormaps["Blues"].resampled(12)
purples = mpl.colormaps["Purples"].resampled(22)
reds = mpl.colormaps["Reds"].resampled(12)
orange = mpl.colormaps["YlOrBr"].resampled(22)
green = mpl.colormaps["YlGn"].resampled(12)
spectrum = mpl.colormaps["viridis"].resampled(3)





c_blues = [blues(i) for i in range(12)]
c_purp = [purples(i) for i in range(22)]
c_red = [reds(i) for i in range(12)]
c_orag = [orange(i) for i in range(22)]
c_spec = [spectrum(i) for i in range(3)]
c_gree = [green(i) for i in range(12)]

# %% [markdown]
# ### QuTip HEOM Calculation data parsing : NC 10 case

# %%
arr = [2,4,6,8,10]

def complex_converter(s):
    return complex(s)

for i in range(len(arr)):
        globals()['arrN{}'.format(arr[i])]=pd.read_csv("./testdataNk{}.txt".format(arr[i]),header=None,delim_whitespace=True)

        for j in range(4):
            globals()['dataN{}col{}'.format(arr[i],j)] = np.array(globals()['arrN{}'.format(arr[i])][1],dtype=complex)
# Out:
# /tmp/ipykernel_10790/322251739.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   globals()['arrN{}'.format(arr[i])]=pd.read_csv("./testdataNk{}.txt".format(arr[i]),header=None,delim_whitespace=True)
# /tmp/ipykernel_10790/322251739.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   globals()['arrN{}'.format(arr[i])]=pd.read_csv("./testdataNk{}.txt".format(arr[i]),header=None,delim_whitespace=True)
# /tmp/ipykernel_10790/322251739.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   globals()['arrN{}'.format(arr[i])]=pd.read_csv("./testdataNk{}.txt".format(arr[i]),header=None,delim_whitespace=True)
# ...

# %% [markdown]
# ### QuTip HEOM Calculation data parsing : NC 20 case

# %%
arr = [2,6,8]

def complex_converter(s):
    return complex(s)

for i in range(len(arr)):
        globals()['arr2N{}'.format(arr[i])]=pd.read_csv("./testdataNc20Nk{}.txt".format(arr[i]),header=None,delim_whitespace=True)

        for j in range(4):
            globals()['data2N{}col{}'.format(arr[i],j)] = np.array(globals()['arrN{}'.format(arr[i])][1],dtype=complex)
# Out:
# /tmp/ipykernel_10790/611114918.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   globals()['arr2N{}'.format(arr[i])]=pd.read_csv("./testdataNc20Nk{}.txt".format(arr[i]),header=None,delim_whitespace=True)
# /tmp/ipykernel_10790/611114918.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   globals()['arr2N{}'.format(arr[i])]=pd.read_csv("./testdataNc20Nk{}.txt".format(arr[i]),header=None,delim_whitespace=True)
# /tmp/ipykernel_10790/611114918.py:7: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   globals()['arr2N{}'.format(arr[i])]=pd.read_csv("./testdataNc20Nk{}.txt".format(arr[i]),header=None,delim_whitespace=True)

# %% [markdown]
# ### Data plot : NC 10 compare

# %%
plt.figure(figsize=(10,8))

plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')

plt.plot(dataN2col1.real,linewidth=0.5,label='Nk2')
plt.plot(dataN4col1.real,linewidth=0.5,label='Nk4')
plt.plot(dataN6col1.real,linewidth=0.5,label='Nk6')
plt.plot(dataN8col1.real,linewidth=0.5,label='Nk8')
plt.plot(dataN10col1.real,linewidth=0.5,label='Nk10')

plt.legend()
plt.show()

# %% [markdown]
# ### Data plot : NC 20 compare

# %%
plt.figure(figsize=(10,8))

plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')

plt.plot(data2N2col1.real,linewidth=0.5,label='Nk2')
plt.plot(data2N6col1.real,linewidth=0.5,label='Nk6')
plt.plot(data2N8col1.real,linewidth=0.5,label='Nk8')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,8))

plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')

plt.plot(dataN2col1.real,linewidth=2,label='Nk2')
#plt.plot(dataN6col1.real,linewidth=0.5,label='Nk6')
#plt.plot(dataN8col1.real,linewidth=0.5,label='Nk8')

plt.plot(data2N2col1.real,linewidth=2,label='Nk2',linestyle='dotted')
#plt.plot(data2N6col1.real,linewidth=0.5,label='Nk6',linestyle='dotted')
#plt.plot(data2N8col1.real,linewidth=0.5,label='Nk8',linestyle='dotted')

plt.legend()
plt.show()
