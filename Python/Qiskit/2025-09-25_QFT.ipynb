# %%
from qiskit import QuantumCircuit, transpile
from qiskit.visualization import plot_bloch_multivector,plot_histogram
from qiskit_aer import AerSimulator

import matplotlib.pyplot as plt
import numpy as np

# %%
qc = QuantumCircuit(2)

qc.initialize([0,0,1,0],[0,1])

# %%
qc.h(0)

qc.cp(np.pi/2,1,0)

qc.h(1)
qc.swap(0,1)

# %%
qc.draw('mpl')

# %%
qc.measure_all()

# AerSimulator로 실행
simulator = AerSimulator()
job = simulator.run(qc, shots=300)
result = job.result()
counts = result.get_counts()

print("QFT 결과:", counts)
plot_histogram(counts)
# Out:
# QFT 결과: {'10 10': 63, '11 11': 69, '00 00': 79, '01 01': 89}

# %%
from qiskit_ibm_runtime import QiskitRuntimeService
service = QiskitRuntimeService()
service.backends()
# Out:
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-09-25 17:13:43,508: Default instance not set. Searching all available instances.
# [<IBMBackend('ibm_strasbourg')>,
#  <IBMBackend('ibm_brussels')>,
#  <IBMBackend('ibm_aachen')>,
#  <IBMBackend('ibm_brisbane')>,
#  <IBMBackend('ibm_fez')>,
#  <IBMBackend('ibm_pittsburgh')>,
#  <IBMBackend('ibm_kingston')>,
#  <IBMBackend('ibm_torino')>,
#  <IBMBackend('ibm_marrakesh')>]

# %%
service.instances()
# Out:
# [{'crn': 'crn:v1:bluemix:public:quantum-computing:eu-de:a/624a449c58db4cebbbcd6d44cd96889e:67df5419-5f99-44de-9ec5-b73ad8925035::',
#   'plan': 'premium',
#   'name': '0_UNIST_UNIST -eu',
#   'tags': []},
#  {'crn': 'crn:v1:bluemix:public:quantum-computing:us-east:a/624a449c58db4cebbbcd6d44cd96889e:a2f23639-8adf-4319-95b5-c73a1934bfa7::',
#   'plan': 'premium',
#   'name': '0_UNIST_UNIST',
#   'tags': []}]
