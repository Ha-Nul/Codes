# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
QiskitRuntimeService.save_account(channel="ibm_cloud", 
                                  token="C6kNr-FN2RE66MaIMGJofZCTcrs6MhC-Z8XaOGhMiipv",
                                instance="crn:v1:bluemix:public:quantum-computing:us-east:a/624a449c58db4cebbbcd6d44cd96889e:a2f23639-8adf-4319-95b5-c73a1934bfa7::"
                                , name="SKKU_TEST"
)

# %%
service = QiskitRuntimeService()
# Out:
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-09-18 17:12:02,986: Default instance not set. Searching all available instances.

# %%
QiskitRuntimeService.delete_account(name='default-ibm-quantum-platform')
# Out:
# True

# %%
service = QiskitRuntimeService()
instances = service.instances()
print("사용 가능한 인스턴스들:")
for instance in instances:
    print(f"- {instance}")
# Out:
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-09-18 17:12:20,856: Default instance not set. Searching all available instances.
# 사용 가능한 인스턴스들:
# - {'crn': 'crn:v1:bluemix:public:quantum-computing:eu-de:a/624a449c58db4cebbbcd6d44cd96889e:67df5419-5f99-44de-9ec5-b73ad8925035::', 'plan': 'premium', 'name': '0_UNIST_UNIST -eu', 'tags': []}
# - {'crn': 'crn:v1:bluemix:public:quantum-computing:us-east:a/624a449c58db4cebbbcd6d44cd96889e:a2f23639-8adf-4319-95b5-c73a1934bfa7::', 'plan': 'premium', 'name': '0_UNIST_UNIST', 'tags': []}
