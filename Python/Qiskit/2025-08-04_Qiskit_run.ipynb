# %%
from qiskit_ibm_runtime import QiskitRuntimeService

# %%
QiskitRuntimeService.save_account(channel="ibm_quantum_platform", token="gWSDtrdmafvHxblMbueLM0qLhDoVmRe1yMKDtekd71L_")

# %%
service = QiskitRuntimeService()
# Out:
# qiskit_runtime_service._resolve_cloud_instances:WARNING:2025-08-04 14:13:58,223: Default instance not set. Searching all available instances.

# %%
QiskitRuntimeService.delete_account(name='default-ibm-quantum')
# Out:
# False
