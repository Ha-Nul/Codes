# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
garray = [0 for i in range(21)]
gsqaure = [0 for i in range(21)]
for i in range(20):
    garray[i+1] = round(garray[i]+0.05,2)
    gsqaure[i+1] = round(garray[i+1]**2,4)

garray2 = [0 for i in range(2)]

for i in range(2):
    garray2[i] = 1 + 0.1*(i+1)

garray2
# Out:
# [1.1, 1.2]

# %%
ta = np.linspace(0,0.4,100)
tau = np.linspace(0,0.4,100)
k = np.full(100,1)
b = 1

COUPLING = [0.001,0.1,0.2,0.3,0.4]

# %%
COUPLING_TRAP_1 = [0.666941,0.693942,0.720636,0.746487,0.771258]
COUPLING_SQ_1 = [0.666942,0.694005,0.720763,0.746674,0.771501]
COUPLING_ED_1 = [6.668945511516176650e-01,6.920440422621382259e-01,7.214319784735002683e-01,7.528093856817774654e-01,7.842378290032503418e-01]

# %%
plt.plot(COUPLING,COUPLING_TRAP_1,linewidth =1,marker='*',label='Trapezoidal')
plt.plot(COUPLING,COUPLING_SQ_1,linewidth=1,marker='x',label='Square')
plt.plot(COUPLING,COUPLING_ED_1,linewidth=1,marker='x',label='Exact Diagonalization')

plt.xlabel(r'$\beta$ ')
plt.ylabel(r'$\chi_{\mathrm{sp}}(\tau = 0)$')

plt.tick_params(axis='x',direction='in')
plt.tick_params(axis='y',direction='in')

plt.text(0.29,0.68,r"$g$ (coupling) = 1")

plt.rcParams['font.family'] = 'Times New Roman'
plt.legend()
plt.grid()


plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
