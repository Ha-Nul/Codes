# %%
import numpy as np
import matplotlib.pyplot as plt
from random import *

R = 100
C = 0.01
t = 0
dt = 0.01
Vb =  3
Q = 0

i=0

Q_arr = []
t_arr = []

while t<1:

    dQ = (Vb-Q/C)*dt/R
    Q = Q + dQ
    Q_arr.append(Q)
    Vc = Q/C
    t = t + dt
    t_arr.append(t)

# %%
plt.plot(t_arr,Q_arr)
plt.show()

# %%
rx = [random() for i in range(3000)]
ry = [random() for i in range(3000)]

x = []
y = []

o_x=[]
o_y=[]

for i in range(len(rx)):
    if (rx[i]**2 + ry[i]**2)**0.5 <= 1:
        x.append(rx[i])
        y.append(ry[i])
    else:
        o_x.append(rx[i])
        o_y.append(ry[i])

compare = len(x)/3000

# %%
plt.figure(figsize=(6,6))
plt.scatter(x,y,color='r')
plt.scatter(o_x,o_y,color='b')
plt.show()

print(compare)
print(3.14/4)
# Out:
# 0.7763333333333333
# 0.785
