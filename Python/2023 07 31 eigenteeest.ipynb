# %%
import sympy as sp
import numpy as np

sp.init_printing()

# %%
r = sp.symbols(r'\gamma')
a = 10
si = sp.sin()
#r = 50

# %%
E_M = sp.Matrix([[0,-r/(2*sp.sqrt(2)),0,0],[-r/(2*sp.sqrt(2)),1,-r/2,0],[0,-r/2,4,-r/2],[0,0,-r/2,9]])
O_M = sp.Matrix([[1,-r/2,0,0],[-r/2,4,-r/2,0],[0,-r/2,9,0],[0,0,-r/2,16]])

# %%
lst_t = E_M.eigenvals()

# %%
lst_tt = O_M.eigenvals()

# %%
x = sp.symbols(r'\lambda')

# %%
li = sp.solve(5*r**2-36-(49-r**2/2)*x-14*x**2-x**3,x)
li[1]
# Out:
#
#
#
#
#
#                                                    2
#                                            3⋅\gamma
#                                            ───────── + 49
#                                                2
# - ────────────────────────────────────────────────────────────────────────────
#                           ____________________________________________________
#                          ╱                      ______________________________
#                         ╱                      ╱
#                        ╱                      ╱                    2     ⎛
#                       ╱                      ╱   ⎛               2⎞      ⎜3⋅\g
#                      ╱                      ╱    ⎝286 - 72⋅\gamma ⎠  - 4⋅⎜────
#     ⎛  1   √3⋅ⅈ⎞    ╱                 2   ╲╱                             ⎝
#   3⋅⎜- ─ - ────⎟⋅3 ╱       - 36⋅\gamma  + ────────────────────────────────────
#     ⎝  2    2  ⎠ ╲╱                                               2
#
# ...

# %%
sp.plot(li[0],li[1],li[2])

# %%
lst = list(lst_t.keys())
sp.plot(lst[0],lst[1],lst[2],lst[3])
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide

# %%
lst2 = list(lst_tt.keys())
sp.plot(lst2[0],lst2[1],lst2[2],lst2[3])

# %%
E_M = np.array([[0,-r/(2*np.sqrt(2)),0,0],[-r/(2*np.sqrt(2)),-1,-r/2,0],[0,-r/2,-4,-r/2],[0,0,-r/2,-9]])
O_M = np.array([[-1,-r/2,0,0],[-r/2,-4,-r/2,0],[0,-r/2,-9,0],[0,0,-r/2,-16]])

# %%
sp.plot(lst[0],lst2[0],lst[1],lst2[1],lst[2],lst2[2],lst[3],lst2[3])
# Out:
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide
# <string>:1: RuntimeWarning: invalid value encountered in scalar power
# <string>:1: RuntimeWarning: invalid value encountered in divide

# %%
f = sp.log(abs((r+8)/(r-8)))

# %%
sp.plot(f)
